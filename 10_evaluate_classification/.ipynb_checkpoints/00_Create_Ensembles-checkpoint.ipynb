# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import balanced_accuracy_score, f1_score, confusion_matrix, matthews_corrcoef

# %%
str_results = pd.read_csv("../run_all_models_scripts/structural_model_held_out_test_results.csv")
phy_results = pd.read_csv("../run_all_models_scripts/physicochemical_model_held_out_test_results.csv")
img_results = pd.read_csv("../run_all_models_scripts/cellpainting_model_held_out_test_results.csv")
ge_results = pd.read_csv("../run_all_models_scripts/LINCSL1000_model_held_out_test_results.csv")
go_results = pd.read_csv("../run_all_models_scripts/GO_model_held_out_test_results.csv")
pid_results = pd.read_csv("../run_all_models_scripts/CellScape_model_held_out_test_results.csv") 
pid_cmu_results = pd.read_csv("../run_all_models_scripts/CellScape_Cmax_unbound_model_held_out_test_results.csv") 
pid_cmt_results = pd.read_csv("../run_all_models_scripts/CellScape_Cmax_total_model_held_out_test_results.csv") 
moa_results = pd.read_csv("../run_all_models_scripts/MOA_model_held_out_test_results.csv") 
moa_cmu_results = pd.read_csv("../run_all_models_scripts/MOA_Cmax_unbound_model_held_out_test_results.csv") 
moa_cmt_results = pd.read_csv("../run_all_models_scripts/MOA_Cmax_total_model_held_out_test_results.csv") 

str_results["Features"] ="Structural"
phy_results["Features"] ="Mordred"
img_results["Features"] ="Cell Painting"
ge_results["Features"] ="LINCSL1000"
go_results["Features"] ="GeneOntology"
pid_results["Features"] ="CellScape"
pid_cmu_results["Features"] ="CellScape with Cmax unbound"
pid_cmt_results["Features"] ="CellScape with Cmax total"
moa_results["Features"] ="MOA"
moa_cmu_results["Features"] ="MOA with Cmax unbound"
moa_cmt_results["Features"] ="MOA with Cmax total"

# %%
str_results
# Out:
#                             Dataset                          Actviity  \
# 0    cardiotox_with_sider_inactives  Cardiotox (with SIDER inactives)
# 1    cardiotox_with_sider_inactives  Cardiotox (with SIDER inactives)
# 2    cardiotox_with_sider_inactives  Cardiotox (with SIDER inactives)
# 3    cardiotox_with_sider_inactives  Cardiotox (with SIDER inactives)
# 4    cardiotox_with_sider_inactives  Cardiotox (with SIDER inactives)
# ..                              ...                               ...
# 456                        DICTrank                          DICTrank
# 457                        DICTrank                          DICTrank
# 458                        DICTrank                          DICTrank
# 459                        DICTrank                          DICTrank
# 460                        DICTrank                          DICTrank
#
#                                                 SMILES  True_Value  \
# 0                   C[NH+](C)CCC=C1c2ccccc2CCc2ccccc21           1
# 1    CC(=O)[NH+]1CCN(c2ccc(OCC3COC(Cn4ccnc4)(c4ccc(...           1
# 2            C=CC1C[NH+]2CCC1CC2C(O)c1ccnc2ccc(OC)cc12           1
# 3                        CC(C)Cc1ccc(C(C)C(=O)[O-])cc1           1
# 4       O=c1n(CCC[NH+]2CCN(c3cccc(Cl)c3)CC2)nc2ccccn12           1
# ..                                                 ...         ...
# 456        COC(=O)N=c1[n-]c2ccc(C(=O)c3ccccc3)cc2[n-]1           0
# 457  CC(C)(C(=O)[O-])c1ccc(C(O)CCC[NH+]2CCC(C(O)(c3...           0
# 458   CCOC(=O)[NH+]1CCC(=C2c3ccc(Cl)cc3CCc3cccnc32)CC1           0
# 459                 CCCSc1ccc2[n-]c(=NC(=O)OC)[n-]c2c1           0
# 460          CCC[NH+](CCC)S(=O)(=O)c1ccc(C(=O)[O-])cc1           0
#
#      Prediction  Probability  Best_Threshold    Features
# 0             1     0.582105        0.518448  Structural
# 1             0     0.483931        0.518448  Structural
# 2             1     0.570043        0.518448  Structural
# 3             1     0.531247        0.518448  Structural
# 4             1     0.727901        0.518448  Structural
# ..          ...          ...             ...         ...
# 456           0     0.553110        0.564024  Structural
# 457           1     0.660163        0.564024  Structural
# 458           1     0.573797        0.564024  Structural
# 459           0     0.498814        0.564024  Structural
# 460           1     0.597749        0.564024  Structural
#
# [461 rows x 8 columns]

# %%
allresults = pd.concat([str_results, phy_results, img_results, ge_results, go_results, 
                        pid_results, 
                        moa_results, pid_cmu_results,
                        pid_cmt_results, moa_cmu_results,
                        moa_cmt_results
                       ]).sort_values(["Dataset", "Features", "SMILES"],
                                                  ascending=[False, False, False]).reset_index(drop=True)
allresults
# Out:
#                      Dataset           Actviity  \
# 0     sider_cardiacdisorders  Cardiac disorders
# 1     sider_cardiacdisorders  Cardiac disorders
# 2     sider_cardiacdisorders  Cardiac disorders
# 3     sider_cardiacdisorders  Cardiac disorders
# 4     sider_cardiacdisorders  Cardiac disorders
# ...                      ...                ...
# 4504                DICTrank           DICTrank
# 4505                DICTrank           DICTrank
# 4506                DICTrank           DICTrank
# 4507                DICTrank           DICTrank
# 4508                DICTrank           DICTrank
#
#                                                  SMILES  True_Value  \
# 0                         c1ccc2c(CC3=[NH+]CCN3)cccc2c1           0
# 1      [O-]c1ccc(C2C[NH2+]CCc3c2cc([O-])c([O-])c3Cl)cc1           1
# 2     [NH3+]C(Cc1cc(I)c(Oc2cc(I)c([O-])c(I)c2)c(I)c1...           1
# 3     OCC[NH+]1CC[NH+](CCCN2c3ccccc3Sc3ccc(C(F)(F)F)...           1
# 4        O=c1n(CCC[NH+]2CCN(c3cccc(Cl)c3)CC2)nc2ccccn12           1
# ...                                                 ...         ...
# 4504                     CC(=O)N=c1[n-]nc(S(N)(=O)=O)s1           0
# 4505           CC(=O)CC(c1ccccc1)c1c([O-])c2ccccc2oc1=O           0
# 4506  CC#CC1(O)CCC2C3=C(C4=C(CC3)CC(=O)CC4)C(c3ccc(N...           1
# 4507          C=CC1C[NH+]2CCC1CC2C(O)c1ccnc2ccc(OC)cc12           1
# 4508  C=CC1=C(C(=O)[O-])[NH+]2C(=O)C(=NC(=O)C([NH2+]...           0
#
#       Prediction  Probability  Best_Threshold       Features
# 0              1     0.574822        0.516513     Structural
# 1              1     0.535648        0.516513     Structural
# 2              0     0.490015        0.516513     Structural
# 3              1     0.741655        0.516513     Structural
# 4              1     0.638864        0.516513     Structural
# ...          ...          ...             ...            ...
# 4504           1     0.892056        0.673120  Cell Painting
# 4505           1     0.900823        0.673120  Cell Painting
# 4506           1     0.784454        0.673120  Cell Painting
# 4507           1     0.820275        0.673120  Cell Painting
# 4508           1     0.772865        0.673120  Cell Painting
#
# [4509 rows x 8 columns]

# %%
def scale_probability(prob, threshold):
    if prob <= threshold:
        return prob / (2 * threshold)
    else:
        return 1 - (1 - prob) / (2 * (1 - threshold))

allresults['Scaled_Probability'] = allresults.apply(lambda row: scale_probability(row['Probability'], row['Best_Threshold']), axis=1)
allresults
# Out:
#                      Dataset           Actviity  \
# 0     sider_cardiacdisorders  Cardiac disorders
# 1     sider_cardiacdisorders  Cardiac disorders
# 2     sider_cardiacdisorders  Cardiac disorders
# 3     sider_cardiacdisorders  Cardiac disorders
# 4     sider_cardiacdisorders  Cardiac disorders
# ...                      ...                ...
# 4504                DICTrank           DICTrank
# 4505                DICTrank           DICTrank
# 4506                DICTrank           DICTrank
# 4507                DICTrank           DICTrank
# 4508                DICTrank           DICTrank
#
#                                                  SMILES  True_Value  \
# 0                         c1ccc2c(CC3=[NH+]CCN3)cccc2c1           0
# 1      [O-]c1ccc(C2C[NH2+]CCc3c2cc([O-])c([O-])c3Cl)cc1           1
# 2     [NH3+]C(Cc1cc(I)c(Oc2cc(I)c([O-])c(I)c2)c(I)c1...           1
# 3     OCC[NH+]1CC[NH+](CCCN2c3ccccc3Sc3ccc(C(F)(F)F)...           1
# 4        O=c1n(CCC[NH+]2CCN(c3cccc(Cl)c3)CC2)nc2ccccn12           1
# ...                                                 ...         ...
# 4504                     CC(=O)N=c1[n-]nc(S(N)(=O)=O)s1           0
# 4505           CC(=O)CC(c1ccccc1)c1c([O-])c2ccccc2oc1=O           0
# 4506  CC#CC1(O)CCC2C3=C(C4=C(CC3)CC(=O)CC4)C(c3ccc(N...           1
# 4507          C=CC1C[NH+]2CCC1CC2C(O)c1ccnc2ccc(OC)cc12           1
# 4508  C=CC1=C(C(=O)[O-])[NH+]2C(=O)C(=NC(=O)C([NH2+]...           0
#
#       Prediction  Probability  Best_Threshold       Features  \
# 0              1     0.574822        0.516513     Structural
# 1              1     0.535648        0.516513     Structural
# 2              0     0.490015        0.516513     Structural
# 3              1     0.741655        0.516513     Structural
# 4              1     0.638864        0.516513     Structural
# ...          ...          ...             ...            ...
# 4504           1     0.892056        0.673120  Cell Painting
# 4505           1     0.900823        0.673120  Cell Painting
# 4506           1     0.784454        0.673120  Cell Painting
# 4507           1     0.820275        0.673120  Cell Painting
# 4508           1     0.772865        0.673120  Cell Painting
#
#       Scaled_Probability
# 0               0.560300
# 1               0.519788
# 2               0.474349
# 3               0.732831
# 4               0.626530
# ...                  ...
# 4504            0.834887
# 4505            0.848298
# 4506            0.670299
# 4507            0.725090
# 4508            0.652572
#
# [4509 rows x 9 columns]

# %%
allresults.Actviity.unique()
# Out:
# array(['Cardiac disorders', 'Cardiotox (with SIDER inactives)',
#        'Cardiotox (with SIDER all)', 'Cardiotox (with SIDER actives)',
#        'DICTrank'], dtype=object)

# %%
for dataset, activity in [('sider_cardiacdisorders','Cardiac disorders'), 
                           ('cardiotox_with_sider_inactives','Cardiotox (with SIDER inactives)'),
           ('cardiotox_with_sider_all','Cardiotox (with SIDER all)'), 
                           ('cardiotox_with_sider_actives','Cardiotox (with SIDER actives)'),
           ('DICTrank', 'DICTrank')]:
            
            print(activity)
            print(dataset)
# Out:
# Cardiac disorders
# sider_cardiacdisorders
# Cardiotox (with SIDER inactives)
# cardiotox_with_sider_inactives
# Cardiotox (with SIDER all)
# cardiotox_with_sider_all
# Cardiotox (with SIDER actives)
# cardiotox_with_sider_actives
# DICTrank
# DICTrank

# %%
allresults
# Out:
#                      Dataset           Actviity  \
# 0     sider_cardiacdisorders  Cardiac disorders
# 1     sider_cardiacdisorders  Cardiac disorders
# 2     sider_cardiacdisorders  Cardiac disorders
# 3     sider_cardiacdisorders  Cardiac disorders
# 4     sider_cardiacdisorders  Cardiac disorders
# ...                      ...                ...
# 4504                DICTrank           DICTrank
# 4505                DICTrank           DICTrank
# 4506                DICTrank           DICTrank
# 4507                DICTrank           DICTrank
# 4508                DICTrank           DICTrank
#
#                                                  SMILES  True_Value  \
# 0                         c1ccc2c(CC3=[NH+]CCN3)cccc2c1           0
# 1      [O-]c1ccc(C2C[NH2+]CCc3c2cc([O-])c([O-])c3Cl)cc1           1
# 2     [NH3+]C(Cc1cc(I)c(Oc2cc(I)c([O-])c(I)c2)c(I)c1...           1
# 3     OCC[NH+]1CC[NH+](CCCN2c3ccccc3Sc3ccc(C(F)(F)F)...           1
# 4        O=c1n(CCC[NH+]2CCN(c3cccc(Cl)c3)CC2)nc2ccccn12           1
# ...                                                 ...         ...
# 4504                     CC(=O)N=c1[n-]nc(S(N)(=O)=O)s1           0
# 4505           CC(=O)CC(c1ccccc1)c1c([O-])c2ccccc2oc1=O           0
# 4506  CC#CC1(O)CCC2C3=C(C4=C(CC3)CC(=O)CC4)C(c3ccc(N...           1
# 4507          C=CC1C[NH+]2CCC1CC2C(O)c1ccnc2ccc(OC)cc12           1
# 4508  C=CC1=C(C(=O)[O-])[NH+]2C(=O)C(=NC(=O)C([NH2+]...           0
#
#       Prediction  Probability  Best_Threshold       Features  \
# 0              1     0.574822        0.516513     Structural
# 1              1     0.535648        0.516513     Structural
# 2              0     0.490015        0.516513     Structural
# 3              1     0.741655        0.516513     Structural
# 4              1     0.638864        0.516513     Structural
# ...          ...          ...             ...            ...
# 4504           1     0.892056        0.673120  Cell Painting
# 4505           1     0.900823        0.673120  Cell Painting
# 4506           1     0.784454        0.673120  Cell Painting
# 4507           1     0.820275        0.673120  Cell Painting
# 4508           1     0.772865        0.673120  Cell Painting
#
#       Scaled_Probability
# 0               0.560300
# 1               0.519788
# 2               0.474349
# 3               0.732831
# 4               0.626530
# ...                  ...
# 4504            0.834887
# 4505            0.848298
# 4506            0.670299
# 4507            0.725090
# 4508            0.652572
#
# [4509 rows x 9 columns]

# %%
# Loop through each dataset
for dataset, activity in [('sider_cardiacdisorders','Cardiac disorders'), 
                          ('cardiotox_with_sider_inactives','Cardiotox (with SIDER inactives)'),
                          ('cardiotox_with_sider_all','Cardiotox (with SIDER all)'), 
                          ('cardiotox_with_sider_actives','Cardiotox (with SIDER actives)'),
                          ('DICTrank', 'DICTrank')]:
    
    
        print()
        print(activity)
        df_dataset = allresults[allresults["Dataset"] == dataset]

        df_ensemble_all = df_dataset.groupby("SMILES").mean().reset_index()
        ensemble_probabilities = df_ensemble_all["Scaled_Probability"]

        # Convert ensemble_proba_dict to ensemble predictions based on threshold
        ensemble_predictions = df_ensemble_all["Scaled_Probability"].apply(lambda x: 1 if x > 0.5 else 0)

        ensemble_predictions_df = pd.DataFrame()
        
 
        ensemble_predictions_df["SMILES"] = df_ensemble_all["SMILES"]
        ensemble_predictions_df['Dataset'] = dataset
        ensemble_predictions_df['Activity'] = activity
        ensemble_predictions_df['True_Value'] = df_ensemble_all["True_Value"]
        ensemble_predictions_df['Prediction'] = ensemble_predictions
        ensemble_predictions_df['Probability'] = ensemble_probabilities
        ensemble_predictions_df['Best_Threshold'] = 0.50
        ensemble_predictions_df['Features'] = "Ensemble_all"
        ensemble_predictions_df.to_csv(f"Ensemble_all_{dataset}.csv", index=False)
# Out:
# Cardiac disorders
#
# Cardiotox (with SIDER inactives)
#
# Cardiotox (with SIDER all)
#
# Cardiotox (with SIDER actives)
#
# DICTrank

# %%
ensemble_predictions_df
# Out:
#                                                SMILES   Dataset  Activity  \
# 0   C=CC1=C(C(=O)[O-])[NH+]2C(=O)C(=NC(=O)C([NH2+]...  DICTrank  DICTrank
# 1           C=CC1C[NH+]2CCC1CC2C(O)c1ccnc2ccc(OC)cc12  DICTrank  DICTrank
# 2   CC#CC1(O)CCC2C3=C(C4=C(CC3)CC(=O)CC4)C(c3ccc(N...  DICTrank  DICTrank
# 3            CC(=O)CC(c1ccccc1)c1c([O-])c2ccccc2oc1=O  DICTrank  DICTrank
# 4                      CC(=O)N=c1[n-]nc(S(N)(=O)=O)s1  DICTrank  DICTrank
# ..                                                ...       ...       ...
# 77  O=c1[n-]c2ccccc2n1C1CC[NH+](CCCC(c2ccc(F)cc2)c...  DICTrank  DICTrank
# 78     O=c1n(CCC[NH+]2CCN(c3cccc(Cl)c3)CC2)nc2ccccn12  DICTrank  DICTrank
# 79                 OC(Cn1cncn1)(Cn1cncn1)c1ccc(F)cc1F  DICTrank  DICTrank
# 80    OCCOCC[NH+]1CC[NH+](C(c2ccccc2)c2ccc(Cl)cc2)CC1  DICTrank  DICTrank
# 81                   [NH3+]CC(CC(=O)[O-])c1ccc(Cl)cc1  DICTrank  DICTrank
#
#     True_Value  Prediction  Probability  Best_Threshold      Features
# 0          0.0           0     0.434076             0.5  Ensemble_all
# 1          1.0           1     0.613035             0.5  Ensemble_all
# 2          1.0           1     0.584910             0.5  Ensemble_all
# 3          0.0           1     0.515083             0.5  Ensemble_all
# 4          0.0           1     0.501829             0.5  Ensemble_all
# ..         ...         ...          ...             ...           ...
# 77         1.0           1     0.672039             0.5  Ensemble_all
# 78         1.0           1     0.657317             0.5  Ensemble_all
# 79         1.0           0     0.492892             0.5  Ensemble_all
# 80         1.0           1     0.599723             0.5  Ensemble_all
# 81         1.0           0     0.483284             0.5  Ensemble_all
#
# [82 rows x 8 columns]

# %%
df_dataset[df_dataset["SMILES"]=="[NH3+]CC(CC(=O)[O-])c1ccc(Cl)cc1"].Scaled_Probability.mean()
# Out:
# 0.4832843218673903

# %%
sider_selected_list= ['Structural', 'Mordred', 'MOA', 'CellScape']

# %%
    # Loop through each dataset
for dataset, activity in [('sider_cardiacdisorders','Cardiac disorders'), 
                          ('cardiotox_with_sider_inactives','Cardiotox (with SIDER inactives)'),
                          ('cardiotox_with_sider_all','Cardiotox (with SIDER all)'), 
                          ('cardiotox_with_sider_actives','Cardiotox (with SIDER actives)'),
                          ('DICTrank', 'DICTrank')]:
        print(dataset)
        df_dataset = allresults[allresults["Dataset"] == dataset]
        # Ensemble_ALL
        grouped = df_dataset.groupby('SMILES')
        # Collect ensemble predictions
        ensemble_proba_dict = {}

        df_ensemble_all = df_dataset[df_dataset.Features.isin(sider_selected_list)].groupby("SMILES").mean().reset_index()
        ensemble_probabilities = df_ensemble_all["Scaled_Probability"]

        # Convert ensemble_proba_dict to ensemble predictions based on threshold
        ensemble_predictions = df_ensemble_all["Scaled_Probability"].apply(lambda x: 1 if x > 0.5 else 0)

        ensemble_predictions_df = pd.DataFrame()
        
        ensemble_predictions_df["SMILES"] = df_ensemble_all["SMILES"]
        ensemble_predictions_df['Dataset'] = dataset
        ensemble_predictions_df['Activity'] = activity
        ensemble_predictions_df['True_Value'] = df_ensemble_all["True_Value"]
        ensemble_predictions_df['Prediction'] = ensemble_predictions
        ensemble_predictions_df['Probability'] = ensemble_probabilities
        ensemble_predictions_df['Best_Threshold'] = 0.50
        ensemble_predictions_df['Features'] = "Ensemble_all"
        ensemble_predictions_df.to_csv(f"Ensemble_selected_{dataset}.csv", index=False)
# Out:
# sider_cardiacdisorders
# cardiotox_with_sider_inactives
# cardiotox_with_sider_all
# cardiotox_with_sider_actives
# DICTrank

# %%
ensemble_predictions_df
# Out:
#                                                SMILES   Dataset  Activity  \
# 0   C=CC1=C(C(=O)[O-])[NH+]2C(=O)C(=NC(=O)C([NH2+]...  DICTrank  DICTrank
# 1           C=CC1C[NH+]2CCC1CC2C(O)c1ccnc2ccc(OC)cc12  DICTrank  DICTrank
# 2   CC#CC1(O)CCC2C3=C(C4=C(CC3)CC(=O)CC4)C(c3ccc(N...  DICTrank  DICTrank
# 3            CC(=O)CC(c1ccccc1)c1c([O-])c2ccccc2oc1=O  DICTrank  DICTrank
# 4                      CC(=O)N=c1[n-]nc(S(N)(=O)=O)s1  DICTrank  DICTrank
# ..                                                ...       ...       ...
# 77  O=c1[n-]c2ccccc2n1C1CC[NH+](CCCC(c2ccc(F)cc2)c...  DICTrank  DICTrank
# 78     O=c1n(CCC[NH+]2CCN(c3cccc(Cl)c3)CC2)nc2ccccn12  DICTrank  DICTrank
# 79                 OC(Cn1cncn1)(Cn1cncn1)c1ccc(F)cc1F  DICTrank  DICTrank
# 80    OCCOCC[NH+]1CC[NH+](C(c2ccccc2)c2ccc(Cl)cc2)CC1  DICTrank  DICTrank
# 81                   [NH3+]CC(CC(=O)[O-])c1ccc(Cl)cc1  DICTrank  DICTrank
#
#     True_Value  Prediction  Probability  Best_Threshold      Features
# 0          0.0           0     0.367026             0.5  Ensemble_all
# 1          1.0           1     0.670322             0.5  Ensemble_all
# 2          1.0           1     0.562531             0.5  Ensemble_all
# 3          0.0           0     0.443971             0.5  Ensemble_all
# 4          0.0           0     0.418193             0.5  Ensemble_all
# ..         ...         ...          ...             ...           ...
# 77         1.0           1     0.676916             0.5  Ensemble_all
# 78         1.0           1     0.719521             0.5  Ensemble_all
# 79         1.0           1     0.512073             0.5  Ensemble_all
# 80         1.0           1     0.591047             0.5  Ensemble_all
# 81         1.0           0     0.449619             0.5  Ensemble_all
#
# [82 rows x 8 columns]

# %%
k =df_dataset[df_dataset.Features.isin(sider_selected_list)]
k[k["SMILES"]=="[NH3+]CC(CC(=O)[O-])c1ccc(Cl)cc1"].Scaled_Probability.mean()
# Out:
# 0.44961918111262206
