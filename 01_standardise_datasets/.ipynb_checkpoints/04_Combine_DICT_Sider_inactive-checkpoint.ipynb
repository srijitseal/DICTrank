# %%
import pandas as pd

sider_cardiacdisorders = pd.read_csv("../data/binarised/sider_cardiacdisorders/sider_cardiacdisorders_binarised.csv.gz", compression="gzip")
DICTrank = pd.read_csv("../data/binarised/DICTrank/DICTrank_binarised.csv.gz", compression="gzip")

# %%
sider_cardiacdisorders = sider_cardiacdisorders.rename(columns={"Cardiac disorders": "Cardiotox"})
sider_cardiacdisorders["source"] = "sider_cardiacdisorders"
sider_cardiacdisorders_inactives = sider_cardiacdisorders[sider_cardiacdisorders["Cardiotox"]==0]
sider_cardiacdisorders_inactives
# Out:
#                                     Standardized_SMILES  \
# 928   NC(Nc1ccc(Cl)cc1)=[NH+]C(N)=[NH+]CCCCCC[NH2+]C...
# 929                         CCCC[NH+]1CC(O)C(O)C(O)C1CO
# 930                    Clc1ccc(C(c2ccccc2Cl)C(Cl)Cl)cc1
# 931   CC1CC2C3CC=C4CC(=O)C=CC4(C)C3(Cl)C(O)CC2(C)C1(...
# 932   Cc1onc(-c2ccccc2)c1C(=O)NC1C(=O)[NH+]2C1SC(C)(...
# ...                                                 ...
# 1317  CC12CCC3c4ccc([O-])cc4CC(CCCCCCCCC[S+](O)CCCC(...
# 1318  Cc1c(C2(c3cc(Br)c([O-])c(Br)c3C)OS(=O)(=O)c3cc...
# 1319  CC(O)C1C(=O)[NH+]2C(C(=O)[O-])=C(SC3C[NH2+]C(C...
# 1320  CC1(C)OC2CC3C4CC=C5CC(=O)CCC5(C)C4(F)C(O)CC3(C...
# 1321  CC1CC2C3CC(F)=C4CC(=O)C=CC4(C)C3(F)C(O)CC2(C)C...
#
#                                      Standardized_InChI  Cardiotox  \
# 928   InChI=1S/C22H30Cl2N10/c23-15-5-9-17(10-6-15)31...          0
# 929   InChI=1S/C10H21NO4/c1-2-3-4-11-5-8(13)10(15)9(...          0
# 930   InChI=1S/C14H10Cl4/c15-10-7-5-9(6-8-10)13(14(1...          0
# 931   InChI=1S/C27H30Cl2O6/c1-15-11-19-18-7-6-16-12-...          0
# 932   InChI=1S/C19H19N3O5S/c1-9-11(12(21-27-9)10-7-5...          0
# ...                                                 ...        ...
# 1317  InChI=1S/C32H47F5O3S/c1-30-17-15-26-25-12-11-2...          0
# 1318  InChI=1S/C21H14Br4O5S/c1-9-12(7-14(22)19(26)17...          0
# 1319  InChI=1S/C15H24N4O6S2/c1-6-11-10(7(2)20)14(21)...          0
# 1320  InChI=1S/C24H32ClFO5/c1-20(2)30-19-10-16-15-6-...          0
# 1321  InChI=1S/C22H28F2O5/c1-11-6-13-14-8-16(23)15-7...          0
#
#                       source
# 928   sider_cardiacdisorders
# 929   sider_cardiacdisorders
# 930   sider_cardiacdisorders
# 931   sider_cardiacdisorders
# 932   sider_cardiacdisorders
# ...                      ...
# 1317  sider_cardiacdisorders
# 1318  sider_cardiacdisorders
# 1319  sider_cardiacdisorders
# 1320  sider_cardiacdisorders
# 1321  sider_cardiacdisorders
#
# [394 rows x 4 columns]

# %%
DICTrank["source"] = "DICTrank"
DICTrank = DICTrank.rename(columns={"DICTrank": "Cardiotox"})
DICTrank = DICTrank [["Standardized_SMILES","Standardized_InChI","Cardiotox","source"]]
DICTrank
# Out:
#                                     Standardized_SMILES  \
# 0       O=C(OC1CC2CC3CC(C1)[NH+]2CC3=O)c1c[nH]c2ccccc12
# 1        O=c1n(CCC[NH+]2CCN(c3cccc(Cl)c3)CC2)nc2ccccn12
# 2     CC(C)COc1ccc(CNC(=O)[NH+](Cc2ccc(F)cc2)C2CC[NH...
# 3                       C[NH+](C)C([NH3+])=NC(N)=[NH2+]
# 4                   CC(C(=O)[O-])c1ccc(-c2ccccc2)c(F)c1
# ...                                                 ...
# 1015                          CCCc1cc(=O)[n-]c(=S)[n-]1
# 1016                            CCc1cc(C([NH3+])=S)ccn1
# 1017                                 CCC1(C)CC(=O)NC1=O
# 1018                 CC[NH+](CC)C(=S)SSC(=S)[NH+](CC)CC
# 1019                              S=c1[n-]cnc2[n-]cnc12
#
#                                      Standardized_InChI  Cardiotox    source
# 0     InChI=1S/C19H20N2O3/c22-18-10-21-12-5-11(18)6-...          1  DICTrank
# 1     InChI=1S/C19H22ClN5O/c20-16-5-3-6-17(15-16)23-...          1  DICTrank
# 2     InChI=1S/C25H34FN3O2/c1-19(2)18-31-24-10-6-20(...          1  DICTrank
# 3     InChI=1S/C4H11N5/c1-9(2)4(7)8-3(5)6/h1-2H3,(H5...          1  DICTrank
# 4     InChI=1S/C15H13FO2/c1-10(15(17)18)12-7-8-13(14...          1  DICTrank
# ...                                                 ...        ...       ...
# 1015  InChI=1S/C7H10N2OS/c1-2-3-5-4-6(10)9-7(11)8-5/...          0  DICTrank
# 1016  InChI=1S/C8H10N2S/c1-2-7-5-6(8(9)11)3-4-10-7/h...          0  DICTrank
# 1017  InChI=1S/C7H11NO2/c1-3-7(2)4-5(9)8-6(7)10/h3-4...          0  DICTrank
# 1018  InChI=1S/C10H20N2S4/c1-5-11(6-2)9(13)15-16-10(...          0  DICTrank
# 1019  InChI=1S/C5H3N4S/c10-5-3-4(7-1-6-3)8-2-9-5/h1-...          0  DICTrank
#
# [1020 rows x 4 columns]

# %%
# Concatenate the dataframes
combined_df = pd.concat([DICTrank, sider_cardiacdisorders_inactives])

# Sort by 'source' column to give precedence to DICTrank rows
combined_df = combined_df.sort_values(by='source')

# Drop duplicates based on 'Standardized_SMILES', keeping the first occurrence
combined_df = combined_df.drop_duplicates(subset='Standardized_SMILES', keep='first').reset_index(drop=True)

# Sort by 'Cardiotox' column to give precedence to toxic
combined_df = combined_df.sort_values(by='Cardiotox', ascending=False)

# Drop duplicates based on 'Standardized_SMILES', keeping the first occurrence
combined_df = combined_df.drop_duplicates(subset='Standardized_SMILES', keep='first').reset_index(drop=True)

combined_df
# Out:
#                                     Standardized_SMILES  \
# 0       O=C(OC1CC2CC3CC(C1)[NH+]2CC3=O)c1c[nH]c2ccccc12
# 1         O=C(C1CCCCC1)[NH+]1CC(=O)[NH+]2CCc3ccccc3C2C1
# 2     CC(C)COc1ccc(CNC(=O)[NH+](Cc2ccc(F)cc2)C2CC[NH...
# 3                       C[NH+](C)C([NH3+])=NC(N)=[NH2+]
# 4                   CC(C(=O)[O-])c1ccc(-c2ccccc2)c(F)c1
# ...                                                 ...
# 1248  O=C(CCCc1ccccc1)OCC(COC(=O)CCCc1ccccc1)OC(=O)C...
# 1249  C=CC[NH+]1CCC23c4c5ccc([O-])c4OC2C(OCCOCCOCCOC...
# 1250                                   OC1COC2C(O)COC12
# 1251            [NH3+]CCCC(O)([P](=O)(=O)O)[P](=O)(=O)O
# 1252  CC1CC2C3CC(F)=C4CC(=O)C=CC4(C)C3(F)C(O)CC2(C)C...
#
#                                      Standardized_InChI  Cardiotox  \
# 0     InChI=1S/C19H20N2O3/c22-18-10-21-12-5-11(18)6-...          1
# 1     InChI=1S/C19H24N2O2/c22-18-13-20(19(23)15-7-2-...          1
# 2     InChI=1S/C25H34FN3O2/c1-19(2)18-31-24-10-6-20(...          1
# 3     InChI=1S/C4H11N5/c1-9(2)4(7)8-3(5)6/h1-2H3,(H5...          1
# 4     InChI=1S/C15H13FO2/c1-10(15(17)18)12-7-8-13(14...          1
# ...                                                 ...        ...
# 1248  InChI=1S/C33H38O6/c34-31(22-10-19-27-13-4-1-5-...          0
# 1249  InChI=1S/C34H53NO11/c1-3-9-35-10-8-33-30-26-4-...          0
# 1250  InChI=1S/C6H10O4/c7-3-1-9-6-4(8)2-10-5(3)6/h3-...          0
# 1251  InChI=1S/C4H11NO7P2/c5-3-1-2-4(6,13(7,8)9)14(1...          0
# 1252  InChI=1S/C22H28F2O5/c1-11-6-13-14-8-16(23)15-7...          0
#
#                       source
# 0                   DICTrank
# 1                   DICTrank
# 2                   DICTrank
# 3                   DICTrank
# 4                   DICTrank
# ...                      ...
# 1248                DICTrank
# 1249                DICTrank
# 1250                DICTrank
# 1251                DICTrank
# 1252  sider_cardiacdisorders
#
# [1253 rows x 4 columns]

# %%
combined_df.Cardiotox.value_counts()
# Out:
# 1    742
# 0    511
# Name: Cardiotox, dtype: int64

# %%
combined_df.Standardized_SMILES.nunique()
# Out:
# 1253

# %%
combined_df.Standardized_InChI.nunique()
# Out:
# 1253

# %%
combined_df.to_csv("../data/binarised/cardiotox_with_sider_inactives/cardiotox_with_sider_inactives_binarised.csv.gz", compression="gzip", index=False)
