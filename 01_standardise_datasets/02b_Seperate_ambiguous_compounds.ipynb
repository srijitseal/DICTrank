# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/DICTrank/DICTrank_processed.csv.gz", compression="gzip")

# %%
ambiguous = df[df["DICT _ Concern"]=="ambiguous"].reset_index(drop=True)
ambiguous
# Out:
#                      Trade Name       Generic/Proper Name(s)  \
# 0           pancuronium bromide          pancuronium bromide
# 1            vecuronium bromide           vecuronium bromide
# 2               doxercalciferol              doxercalciferol
# 3      ergocalciferol capsules,     ergocalciferol capsules,
# 4                   doxycycline                  doxycycline
# ..                          ...                          ...
# 94                     dextrose                     dextrose
# 95                   didanosine                   didanosine
# 96                     oxazepam                     oxazepam
# 97                    lorazepam                    lorazepam
# 98  technetium tc 99m medronate  technetium tc 99m medronate
#
#    Active Ingredient(s)                                             SMILES  \
# 0   pancuronium bromide  [Br-].[Br-].[H][C@@]1(C[C@@]2([H])[C@]3([H])CC...
# 1    vecuronium bromide  [Br-].CC(=O)O[C@H]1[C@H](C[C@H]2[C@@H]3CC[C@H]...
# ...

# %%
DICTrank_binarised = pd.read_csv("../data/binarised/DICTrank/DICTrank_binarised.csv.gz", 
                                 compression="gzip")
DICTrank_binarised
# Out:
#                    Trade Name   Generic/Proper Name(s)  \
# 0                     anzemet      dolasetron mesylate
# 1     trazodone hydrochloride  trazodone hydrochloride
# 2                    nuplazid    pimavanserin tartrate
# 3     metformin hydrochloride  metformin hydrochloride
# 4                flurbiprofen             flurbiprofen
# ...                       ...                      ...
# 1015         propylthiouracil         propylthiouracil
# 1016                 trecator              ethionamide
# 1017             ethosuximide             ethosuximide
# 1018               disulfiram               disulfiram
# 1019               purinethol           mercaptopurine
#
#          Active Ingredient(s) DICT _ Concern  \
# 0         dolasetron mesylate           most
# 1     trazodone hydrochloride           most
# 2       pimavanserin tartrate           most
# 3     metformin hydrochloride           most
# 4                flurbiprofen           most
# ...

# %%
ambiguous = ambiguous[~ambiguous.Standardized_SMILES.isin(DICTrank_binarised.Standardized_SMILES.to_list())]

# %%
ambiguous= ambiguous.reset_index(drop=True)

# %%
ambiguous.to_csv("../14_Predict_ambiguous_compounds/DICTrank_ambiguous_compounds.csv.gz", compression="gzip")
