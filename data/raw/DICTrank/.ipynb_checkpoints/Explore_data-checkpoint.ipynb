# %%
import pandas as pd

# %%
df = pd.read_csv("Get_smiles/DICTrank.csv", encoding='ISO-8859-1')
df
# Out:
#                       Trade Name      Generic/Proper Name(s)  \
# 0               zyprexa relprevv          olanzapine pamoate
# 1     indium in 111 oxyquinoline  indium in-111 oxyquinoline
# 2                   ammonia n 13                ammonia n-13
# 3           sodium fluoride f 18        sodium fluoride f 18
# 4                         tauvid           flortaucipir f-18
# ...                          ...                         ...
# 1294                      nardil          phenelzine sulfate
# 1295            amikacin sulfate            amikacin sulfate
# 1296                streptomycin                streptomycin
# 1297                  tobramycin          tobramycin sulfate
# 1298                  purinethol              mercaptopurine
#
#             Active Ingredient(s)  \
# 0             olanzapine pamoate
# 1     indium in-111 oxyquinoline
# 2                   ammonia n-13
# 3           sodium fluoride f-18
# 4              flortaucipir f-18
# ...

# %%
df = df.drop_duplicates(subset=["SMILES", "DICT _ Concern"], keep="first").reset_index(drop=True)
df
# Out:
#                       Trade Name      Generic/Proper Name(s)  \
# 0               zyprexa relprevv          olanzapine pamoate
# 1     indium in 111 oxyquinoline  indium in-111 oxyquinoline
# 2                   ammonia n 13                ammonia n-13
# 3           sodium fluoride f 18        sodium fluoride f 18
# 4                         tauvid           flortaucipir f-18
# ...                          ...                         ...
# 1270                      nardil          phenelzine sulfate
# 1271            amikacin sulfate            amikacin sulfate
# 1272                streptomycin                streptomycin
# 1273                  tobramycin          tobramycin sulfate
# 1274                  purinethol              mercaptopurine
#
#             Active Ingredient(s)  \
# 0             olanzapine pamoate
# 1     indium in-111 oxyquinoline
# 2                   ammonia n-13
# 3           sodium fluoride f-18
# 4              flortaucipir f-18
# ...

# %%
df.to_csv("DICTrank.csv.gz", compression="gzip", index=False)
