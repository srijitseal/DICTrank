# %%
import pandas as pd

# %%
df = pd.read_csv("Cmax.csv.gz", compression="gzip")
df
# Out:
#                                                 SMILES  \
# 0                                   C#CC(O)(/C=C/Cl)CC
# 1                                 C#CC1(OC(N)=O)CCCCC1
# 2    C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=Cc5oncc5C[C@]4(...
# 3        C(=C/c1ccccc1)\CN1CCN(C(c2ccccc2)c2ccccc2)CC1
# 4    C/C=C/C[C@@H](C)[C@@H](O)[C@H]1C(=O)N[C@@H](CC...
# ..                                                 ...
# 754                               Oc1nc(O)c2cn[nH]c2n1
# 755                                  Oc1ncnc2[nH]ncc12
# 756                                  Sc1ncnc2nc[nH]c12
# 757                        c1ccc([C@H]2CN3CCSC3=N2)cc1
# 758                         c1cnc2cc3c(cc2n1)C1CNCC3C1
#
#      median pMolar total plasma concentration  \
# 0                                    4.257078
# 1                                    4.223262
# 2                                    6.227192
# 3                                    6.047947
# 4                                    6.111649
# ...
