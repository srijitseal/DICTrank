# %%
import pandas as pd

# %%
df = pd.read_csv("GO_transformed_signatures_PAEA.csv.gz", compression="gzip")

# %%
df
# Out:
#              pert_id  substantia nigra development (GO:0021762)  \
# 0      BRD-A00100033                                     2.3522
# 1      BRD-A00150179                                     0.6902
# 2      BRD-A00267231                                     5.4935
# 3      BRD-A00420644                                     0.7070
# 4      BRD-A00474148                                     0.3655
# ...              ...                                        ...
# 20333  BRD-U66370498                                     9.0322
# 20334  BRD-U73308409                                     2.1013
# 20335  BRD-U77632492                                     0.1185
# 20336  BRD-U88459701                                     0.0063
# 20337  BRD-U94846492                                     2.7948
#
#        L-methionine salvage (GO:0071267)  gamma-tubulin binding (GO:0043015)  \
# 0                                 1.9099                              0.2668
# ...
