# %%
import pandas as pd

# %%
df = pd.read_csv("GeneOntology_overlaps.csv.gz", compression="gzip")

# %%
df
# Out:
#                                     Standardized_SMILES  \
# 0                          BrC1C(Br)C(Br)C(Br)C(Br)C1Br
# 1                          Brc1c(Br)c(Br)c2[n-]nnc2c1Br
# 2                       Brc1c(NC2=[NH+]CCN2)ccc2nccnc12
# 3            Brc1cc2c(cc1C1[NH2+]c3ccccc3C3C=CCC31)OCO2
# 4          C#CC1(O)CCC2C3=C(C=CC21CC)C1=C(CC3)CC(=O)CC1
# ...                                                 ...
# 2409                            c1cncc(C2CCCC[NH2+]2)c1
# 2410                             c1cncc(C2CCC[NH2+]2)c1
# 2411                    c1coc(CN=c2[n-]cnc3[n-]cnc23)c1
# 2412                         c1nc(CC2CC[NH2+]CC2)c[n-]1
# 2413  c1nc2[n-]c(=Nc3ccc(N4CCOCC4)cc3)[n-]c(=NC3CCCC...
#
#       substantia nigra development (GO:0021762)  \
# 0                                        4.1336
# 1                                        0.3718
# 2                                        0.9815
# 3                                        1.4305
# ...
