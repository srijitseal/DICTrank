# %%
import pandas as pd

# %%
df = pd.read_csv("GeneOntology_processed.csv.gz")

# %%
df
# Out:
#                                     Standardized_SMILES  \
# 0                          BrC1C(Br)C(Br)C(Br)C(Br)C1Br
# 1                          Brc1c(Br)c(Br)c2[n-]nnc2c1Br
# 2                       Brc1c(NC2=[NH+]CCN2)ccc2nccnc12
# 3            Brc1cc2c(cc1C1[NH2+]c3ccccc3C3C=CCC31)OCO2
# 4            Brc1ccc(-c2csc(N3CCC(c4nn[n-]n4)CC3)n2)cc1
# ...                                                 ...
# 9127    c1nc(=NCc2ccc3c(c2)OCO3)c2cc(-c3ccoc3)ccc2[n-]1
# 9128                         c1nc(CC2CC[NH2+]CC2)c[n-]1
# 9129                       c1nc(CCCC2CC[NH2+]CC2)c[n-]1
# 9130  c1nc2[n-]c(=Nc3ccc(N4CCOCC4)cc3)[n-]c(=NC3CCCC...
# 9131  c1ncc(-c2ccc(C3C4C[NH+](Cc5ccc6c(c5)OCO6)CC3[N...
#
#       substantia nigra development (GO:0021762)  \
# 0                                        4.1336
# 1                                        0.3718
# 2                                        0.9815
# 3                                        1.4305
# ...
