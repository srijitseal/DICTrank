# %%
import pandas as pd

# %%
df = pd.read_csv("LINCS_Gene_Experssion_signatures_CD.csv.gz", compression="gzip")

# %%
df
# Out:
#              pert_id  200814_at  222103_at  201453_x_at  204131_s_at  \
# 0      BRD-A00100033     0.0193     0.0260      -0.0136       0.0283
# 1      BRD-A00150179    -0.0197    -0.0058      -0.0243       0.0088
# 2      BRD-A00267231    -0.0370     0.0010       0.0115       0.0271
# 3      BRD-A00420644     0.0109    -0.0258       0.0221      -0.0354
# 4      BRD-A00474148    -0.0033     0.0042      -0.0131       0.0130
# ...              ...        ...        ...          ...          ...
# 20334  BRD-U66370498    -0.0207    -0.0337       0.0111      -0.0172
# 20335  BRD-U73308409     0.0537     0.0144       0.0004       0.0473
# 20336  BRD-U77632492    -0.0042    -0.0145      -0.0013       0.0139
# 20337  BRD-U88459701    -0.0082     0.0077      -0.0047       0.0150
# 20338  BRD-U94846492     0.0238     0.0018       0.0038      -0.0332
#
#        200059_s_at  205067_at  213702_x_at  214435_x_at  201334_s_at  ...  \
# ...

# %%
smiles= pd.read_csv("meta_SMILES.csv")
smiles
# Out:
#                     pert_id           pert_iname  pubchem_cid  \
# 0             BRD-A00037023        BRD-A00037023          NaN
# 1             BRD-A00051892        BRD-A00051892          NaN
# 2             BRD-A00100033           NIFURTIMOX    6842999.0
# 3             BRD-A00150179  5-HYDROXYTRYPTOPHAN     589768.0
# 4             BRD-A00214921        BRD-A00214921          NaN
# ...                     ...                  ...          ...
# 41769         CMAP-ERGKD328         ASSINEX_D328          NaN
# 41770      CMAP-PRISM-1B-NR                1B-NR          NaN
# 41771  CMAP-PRISM-1B-PARENT            1B-PARENT          NaN
# 41772        CMAP-PRISM-TP7                  TP7          NaN
# 41773   CMAP-T2DTUNICAMYCIN          TUNICAMYCIN          NaN
#
#                                                   SMILES
# 0      CCOC(=O)C1=C(C)N=C2SC(=CC(=O)N2C1c1ccc(OC)cc1)...
# 1                          N#Cc1nc(oc1NCC1CCCO1)-c1cccs1
# ...

# %%
df = pd.merge(smiles, df)
df = df.drop(columns=["pert_iname", "pubchem_cid"])
df
# Out:
#              pert_id                                             SMILES  \
# 0      BRD-A00100033          CC1CS(=O)(=O)CCN1N=Cc1ccc(o1)[N+]([O-])=O
# 1      BRD-A00150179                     NC(Cc1c[nH]c2cccc(O)c12)C(O)=O
# 2      BRD-A00267231          CCCCC#Cc1nc(NC)c2ncn(C3OC(CO)C(O)C3O)c2n1
# 3      BRD-A00420644               CCN1C2C(C(=NC2Nc3ccccc13)OC)c4ccccc4
# 4      BRD-A00474148  Oc1ccc(cc1)N1CCN(CC1)[S+]([O-])(=O)c1ccc2NC(=O...
# ...              ...                                                ...
# 20334  BRD-U66370498  C[C@@]34CC[C@H]2[C@@H](CCC1CCCC(O)[C@@]12C)[C@...
# 20335  BRD-U73308409  CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=...
# 20336  BRD-U77632492         COC1=CC=CC(=C1)NC(=O)CN2C(=O)C3=CC=CC=C3S2
# 20337  BRD-U88459701  O=C(O)C[C@H](O)C[C@H](O)CCn2c(c(c(c2c1ccc(F)cc...
# 20338  BRD-U94846492  O(c4cc1c(nccc1[C@@H](O)[C@H]2N3CC[C@@H](C2)[C@...
#
#        200814_at  222103_at  201453_x_at  204131_s_at  200059_s_at  205067_at  \
# ...

# %%
df.pert_id.nunique()
# Out:
# 20339

# %%
smiles = df[["pert_id","SMILES"]]
smiles
# Out:
#              pert_id                                             SMILES
# 0      BRD-A00100033          CC1CS(=O)(=O)CCN1N=Cc1ccc(o1)[N+]([O-])=O
# 1      BRD-A00150179                     NC(Cc1c[nH]c2cccc(O)c12)C(O)=O
# 2      BRD-A00267231          CCCCC#Cc1nc(NC)c2ncn(C3OC(CO)C(O)C3O)c2n1
# 3      BRD-A00420644               CCN1C2C(C(=NC2Nc3ccccc13)OC)c4ccccc4
# 4      BRD-A00474148  Oc1ccc(cc1)N1CCN(CC1)[S+]([O-])(=O)c1ccc2NC(=O...
# ...              ...                                                ...
# 20334  BRD-U66370498  C[C@@]34CC[C@H]2[C@@H](CCC1CCCC(O)[C@@]12C)[C@...
# 20335  BRD-U73308409  CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=...
# 20336  BRD-U77632492         COC1=CC=CC(=C1)NC(=O)CN2C(=O)C3=CC=CC=C3S2
# 20337  BRD-U88459701  O=C(O)C[C@H](O)C[C@H](O)CCn2c(c(c(c2c1ccc(F)cc...
# 20338  BRD-U94846492  O(c4cc1c(nccc1[C@@H](O)[C@H]2N3CC[C@@H](C2)[C@...
#
# [20339 rows x 2 columns]

# %%
smiles.to_csv("../raw/GeneExpressionSMILES/GeneExpressionSMILES.csv.gz", index=False, compression="gzip")
smiles
# Out:
#              pert_id                                             SMILES
# 0      BRD-A00100033          CC1CS(=O)(=O)CCN1N=Cc1ccc(o1)[N+]([O-])=O
# 1      BRD-A00150179                     NC(Cc1c[nH]c2cccc(O)c12)C(O)=O
# 2      BRD-A00267231          CCCCC#Cc1nc(NC)c2ncn(C3OC(CO)C(O)C3O)c2n1
# 3      BRD-A00420644               CCN1C2C(C(=NC2Nc3ccccc13)OC)c4ccccc4
# 4      BRD-A00474148  Oc1ccc(cc1)N1CCN(CC1)[S+]([O-])(=O)c1ccc2NC(=O...
# ...              ...                                                ...
# 20334  BRD-U66370498  C[C@@]34CC[C@H]2[C@@H](CCC1CCCC(O)[C@@]12C)[C@...
# 20335  BRD-U73308409  CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=...
# 20336  BRD-U77632492         COC1=CC=CC(=C1)NC(=O)CN2C(=O)C3=CC=CC=C3S2
# 20337  BRD-U88459701  O=C(O)C[C@H](O)C[C@H](O)CCn2c(c(c(c2c1ccc(F)cc...
# 20338  BRD-U94846492  O(c4cc1c(nccc1[C@@H](O)[C@H]2N3CC[C@@H](C2)[C@...
#
# [20339 rows x 2 columns]

# %%
smiles.pert_id.nunique()
# Out:
# 20339
